# %% [markdown]
# <a href="https://colab.research.google.com/github/ainurafifah00/Coursera_TF/blob/master/%5BWeek_1%5D_TF_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Week 1
#
# A New Programming Paradigm

# %%
# !pip install tensorflow==2.0.0-alpha0

# %% [markdown]
# Try It Yourself

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ### Neural Networks
#
# Next we will create the simplest possible neural network. It has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# The LOSS function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the OPTIMIZER function to make another guess. Based on how the loss function went, it will try to minimize the loss.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ### Data

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# ### Training Neural Network

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 8ms/sample - loss: 48.8411
# Epoch 2/500
# 6/6 [==============================] - 0s 296us/sample - loss: 47.7847
# Epoch 3/500
# 6/6 [==============================] - 0s 338us/sample - loss: 46.7520
# Epoch 4/500
# 6/6 [==============================] - 0s 367us/sample - loss: 45.7424
# Epoch 5/500
# 6/6 [==============================] - 0s 322us/sample - loss: 44.7554
# Epoch 6/500
# 6/6 [==============================] - 0s 339us/sample - loss: 43.7904
# Epoch 7/500
# 6/6 [==============================] - 0s 367us/sample - loss: 42.8471
# Epoch 8/500
# 6/6 [==============================] - 0s 339us/sample - loss: 41.9249
# Epoch 9/500
# 6/6 [==============================] - 0s 358us/sample - loss: 41.0234
# Epoch 10/500
# 6/6 [==============================] - 0s 354us/sample - loss: 40.1420
# Epoch 11/500
# 6/6 [==============================] - 0s 334us/sample - loss: 39.2804
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[16.402653]]

# %% [markdown]
# 2 reasons why it's not exactly 19.0:
#
# a. The first is that you trained it using very little data. There's only six points.
#
# b. When using neural networks, as they try to figure out the answers for everything, they deal in probability. You'll have to adjust how you handle answers to fit

# %% [markdown]
# ##Exercise 1 : Housing Prices

# %% [markdown]
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# So, imagine if house pricing was as easy as a house costs 50k + 50k per bedroom, so that a 1 bedroom house costs 100k, a 2 bedroom house costs 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

house = 50
prices = []
room = []

for i in range(6):
  i = i + 1
  room.append(i)

for additional_room in range(6):
  house = house + 50
  prices.append(house)




# GRADED FUNCTION: house_model
def house_model(y_new):
    #xs = np.array(prices, dtype=float)
    #ys = np.array(room, dtype=float)
    xs = room
    ys = prices
    model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
    model.compile(optimizer='sgd', loss='mean_squared_error')
    model.fit(xs, ys, epochs=500)
    return model.predict(y_new)[0]

prediction = house_model([7.0])
print(prediction)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 8ms/sample - loss: 55837.5898
# Epoch 2/500
# 6/6 [==============================] - 0s 321us/sample - loss: 52340.5977
# Epoch 3/500
# 6/6 [==============================] - 0s 504us/sample - loss: 49063.6055
# Epoch 4/500
# 6/6 [==============================] - 0s 770us/sample - loss: 45992.7695
# Epoch 5/500
# 6/6 [==============================] - 0s 391us/sample - loss: 43115.1289
# Epoch 6/500
# 6/6 [==============================] - 0s 399us/sample - loss: 40418.5195
# Epoch 7/500
# 6/6 [==============================] - 0s 422us/sample - loss: 37891.5586
# Epoch 8/500
# 6/6 [==============================] - 0s 532us/sample - loss: 35523.5664
# Epoch 9/500
# 6/6 [==============================] - 0s 608us/sample - loss: 33304.5391
# Epoch 10/500
# 6/6 [==============================] - 0s 395us/sample - loss: 31225.1191
# Epoch 11/500
# 6/6 [==============================] - 0s 464us/sample - loss: 29276.5098
# ...

# %%
# Now click the 'Submit Assignment' button above.
# Once that is complete, please run the following two cells to save your work and close the notebook


# %%javascript
<!-- Save the notebook -->
IPython.notebook.save_checkpoint();

# %%javascript
<!-- Shutdown and close the notebook -->
window.onbeforeunload = null
window.close();
IPython.notebook.session.delete();
